# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.max_columns = 100

# %%
df_price = pd.read_csv('price_demand_data.csv')
df_price.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0   VIC1  1/01/2021 0:30      4179.21           LOW
# 1   VIC1  1/01/2021 1:00      4047.76           LOW
# 2   VIC1  1/01/2021 1:30      3934.70           LOW
# 3   VIC1  1/01/2021 2:00      3766.45           LOW
# 4   VIC1  1/01/2021 2:30      3590.37           LOW

# %%
df_price["SETTLEMENTDATE"] = pd.to_datetime(df_price["SETTLEMENTDATE"])
df_price["SETTLEMENTDATE"] = df_price["SETTLEMENTDATE"].dt.date
df_price.head()
# Out:
#   REGION SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0   VIC1     2021-01-01      4179.21           LOW
# 1   VIC1     2021-01-01      4047.76           LOW
# 2   VIC1     2021-01-01      3934.70           LOW
# 3   VIC1     2021-01-01      3766.45           LOW
# 4   VIC1     2021-01-01      3590.37           LOW

# %%
df_price["PRICECATEGORY"].value_counts()
# Out:
# LOW        7570
# MEDIUM     3061
# HIGH        777
# EXTREME     256
# Name: PRICECATEGORY, dtype: int64

# %%
df_price['PRICECATEG'] = df_price['PRICECATEGORY'].replace(['LOW','MEDIUM','HIGH','EXTREME'],[0,1,2,3])

# %%
df_price['PRICECATEGORY'].value_counts()
# Out:
# LOW        7570
# MEDIUM     3061
# HIGH        777
# EXTREME     256
# Name: PRICECATEGORY, dtype: int64

# %%
df_price['PRICECATEG'].value_counts()
# Out:
# 0    7570
# 1    3061
# 2     777
# 3     256
# Name: PRICECATEG, dtype: int64

# %%
df_price.loc[df_price['PRICECATEG'] == 1]
# Out:
#       REGION SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY  PRICECATEG
# 373     VIC1     2021-08-01      5352.25        MEDIUM           1
# 374     VIC1     2021-08-01      5321.80        MEDIUM           1
# 417     VIC1     2021-09-01      5452.03        MEDIUM           1
# 418     VIC1     2021-09-01      5653.12        MEDIUM           1
# 419     VIC1     2021-09-01      5812.76        MEDIUM           1
# ...      ...            ...          ...           ...         ...
# 11659   VIC1     2021-08-31      4861.91        MEDIUM           1
# 11660   VIC1     2021-08-31      4748.74        MEDIUM           1
# 11661   VIC1     2021-08-31      4620.09        MEDIUM           1
# 11662   VIC1     2021-08-31      4834.00        MEDIUM           1
# 11663   VIC1     2021-01-09      4811.27        MEDIUM           1
#
# [3061 rows x 5 columns]

# %%
#A model which predicts the maximum daily price category based on the provided weather data.

# for each day, find the maximum price category
df_price_max = df_price.groupby("SETTLEMENTDATE").max()
df_price_max.reset_index(inplace=True)

# %%
df_price_max
# Out:
#     SETTLEMENTDATE REGION  TOTALDEMAND PRICECATEGORY  PRICECATEG
# 0       2021-01-01   VIC1      5019.64           LOW           0
# 1       2021-01-02   VIC1      5228.29        MEDIUM           1
# 2       2021-01-03   VIC1      5225.37           LOW           0
# 3       2021-01-04   VIC1      5807.02        MEDIUM           1
# 4       2021-01-05   VIC1      5261.09        MEDIUM           1
# ..             ...    ...          ...           ...         ...
# 239     2021-12-04   VIC1      6415.58        MEDIUM           2
# 240     2021-12-05   VIC1      6406.00        MEDIUM           3
# 241     2021-12-06   VIC1      6062.58        MEDIUM           3
# 242     2021-12-07   VIC1      7095.00        MEDIUM           2
# 243     2021-12-08   VIC1      6537.70        MEDIUM           2
#
# [244 rows x 5 columns]

# %%
df_price_max = pd.DataFrame(df_price.groupby("SETTLEMENTDATE").PRICECATEG.max())
#df_price_max.reset_index(inplace=True)

# %%
df_price_max
# Out:
#                 PRICECATEG
# SETTLEMENTDATE
# 2021-01-01               0
# 2021-01-02               1
# 2021-01-03               0
# 2021-01-04               1
# 2021-01-05               1
# ...                    ...
# 2021-12-04               2
# 2021-12-05               3
# 2021-12-06               3
# 2021-12-07               2
# 2021-12-08               2
#
# [244 rows x 1 columns]

# %%
df_price_max.reset_index(inplace=True)

# %%
df_price_max
# Out:
#     SETTLEMENTDATE  PRICECATEG
# 0       2021-01-01           0
# 1       2021-01-02           1
# 2       2021-01-03           0
# 3       2021-01-04           1
# 4       2021-01-05           1
# ..             ...         ...
# 239     2021-12-04           2
# 240     2021-12-05           3
# 241     2021-12-06           3
# 242     2021-12-07           2
# 243     2021-12-08           2
#
# [244 rows x 2 columns]

# %%
df_price_max["SETTLEMENTDATE"] = pd.to_datetime(df_price_max["SETTLEMENTDATE"])

# %%
df_price_max["PRICECATEG"].value_counts()
# Out:
# 1    77
# 3    64
# 2    61
# 0    42
# Name: PRICECATEG, dtype: int64

# %%
df_price_max.shape
# Out:
# (244, 2)

# %%
df_weather = pd.read_csv('weather_data.csv')
df_weather.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0  1/01/2021                      15.6                      29.9
# 1  2/01/2021                      18.4                      29.0
# 2  3/01/2021                      17.0                      26.2
# 3  4/01/2021                      16.0                      18.6
# 4  5/01/2021                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# 2                             WSW                               33.0
# 3                             SSE                               41.0
# 4                             SSE                               35.0
#
#   Time of maximum wind gust  9am Temperature (°C)  9am relative humidity (%)  \
# 0                     13:14                  19.2                       77.0
# 1                      8:22                  23.3                       52.0
# 2                     17:55                  18.3                      100.0
# 3                     16:03                  16.2                       98.0
# 4                     11:02                  17.2                       96.0
#
#    9am cloud amount (oktas) 9am wind direction 9am wind speed (km/h)  \
# 0                         6                  N                     2
# 1                         7                NNW                    17
# 2                         8                WSW                     4
# 3                         8                SSE                    11
# 4                         8                SSE                    13
#
#    9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                  1018.8                  28.1                         43
# 1                  1013.3                  28.7                         38
# 2                  1007.7                  23.5                         59
# 3                  1010.0                  18.2                         82
# 4                  1012.5                  18.2                         82
#
#    3pm cloud amount (oktas) 3pm wind direction 3pm wind speed (km/h)  \
# 0                       5.0                  E                    13
# 1                       7.0                 SW                     4
# 2                       4.0                SSW                     2
# 3                       8.0                SSW                    17
# 4                       8.0                SSE                    19
#
#    3pm MSL pressure (hPa)
# 0                  1015.3
# 1                  1008.5
# 2                  1005.2
# 3                  1011.0
# 4                  1013.3

# %%
df_weather["Date"] = pd.to_datetime(df_weather["Date"], format="%d/%m/%Y")
df_weather.head()
# Out:
#         Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0 2021-01-01                      15.6                      29.9
# 1 2021-01-02                      18.4                      29.0
# 2 2021-01-03                      17.0                      26.2
# 3 2021-01-04                      16.0                      18.6
# 4 2021-01-05                      15.9                      19.1
#
#    Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0            0.0               2.8               9.3
# 1            0.0               9.4               1.3
# 2           12.6               4.8               7.1
# 3            2.6               3.8               0.0
# 4           11.2               1.0               0.0
#
#   Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                             NNE                               31.0
# 1                             NNW                               30.0
# 2                             WSW                               33.0
# 3                             SSE                               41.0
# 4                             SSE                               35.0
#
#   Time of maximum wind gust  9am Temperature (°C)  9am relative humidity (%)  \
# 0                     13:14                  19.2                       77.0
# 1                      8:22                  23.3                       52.0
# 2                     17:55                  18.3                      100.0
# 3                     16:03                  16.2                       98.0
# 4                     11:02                  17.2                       96.0
#
#    9am cloud amount (oktas) 9am wind direction 9am wind speed (km/h)  \
# 0                         6                  N                     2
# 1                         7                NNW                    17
# 2                         8                WSW                     4
# 3                         8                SSE                    11
# 4                         8                SSE                    13
#
#    9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                  1018.8                  28.1                         43
# 1                  1013.3                  28.7                         38
# 2                  1007.7                  23.5                         59
# 3                  1010.0                  18.2                         82
# 4                  1012.5                  18.2                         82
#
#    3pm cloud amount (oktas) 3pm wind direction 3pm wind speed (km/h)  \
# 0                       5.0                  E                    13
# 1                       7.0                 SW                     4
# 2                       4.0                SSW                     2
# 3                       8.0                SSW                    17
# 4                       8.0                SSE                    19
#
#    3pm MSL pressure (hPa)
# 0                  1015.3
# 1                  1008.5
# 2                  1005.2
# 3                  1011.0
# 4                  1013.3

# %%
df_weather.shape
# Out:
# (243, 21)

# %%
# merge the weather data with the price data
df = pd.merge(df_price_max, df_weather, left_on="SETTLEMENTDATE", right_on="Date")

# %%
to_drop = ["SETTLEMENTDATE", "Date"]
df.drop(to_drop, axis=1, inplace=True)

# %%
df
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 207            0.0               1.2               3.8
# 208            0.0               1.6               9.6
# 209            0.6               6.4               4.3
# 210            4.0               1.4               7.4
# 211            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 207                             SSW                               15.0
# 208                               N                               39.0
# 209                             NNE                               33.0
# 210                             NNW                               50.0
# 211                               N                               61.0
#
#     Time of maximum wind gust  9am Temperature (°C)  \
# 0                       13:14                  19.2
# 1                        8:22                  23.3
# 2                       17:55                  18.3
# 3                       16:03                  16.2
# 4                       11:02                  17.2
# ..                        ...                   ...
# 207                     12:18                   7.7
# 208                     13:14                   9.1
# 209                      1:50                  10.6
# 210                     14:04                  11.1
# 211                     16:29                  13.5
#
#      9am relative humidity (%)  9am cloud amount (oktas) 9am wind direction  \
# 0                         77.0                         6                  N
# 1                         52.0                         7                NNW
# 2                        100.0                         8                WSW
# 3                         98.0                         8                SSE
# 4                         96.0                         8                SSE
# ..                         ...                       ...                ...
# 207                       88.0                         7
# 208                       80.0                         1                  N
# 209                       79.0                         7                  N
# 210                       70.0                         7                  N
# 211                       53.0                         7                  N
#
#     9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                       2                  1018.8                  28.1
# 1                      17                  1013.3                  28.7
# 2                       4                  1007.7                  23.5
# 3                      11                  1010.0                  18.2
# 4                      13                  1012.5                  18.2
# ..                    ...                     ...                   ...
# 207                  Calm                  1020.0                  12.8
# 208                     7                  1018.6                  17.4
# 209                    13                  1011.4                  12.8
# 210                    15                  1016.1                  16.8
# 211                    17                     NaN                  19.4
#
#      3pm relative humidity (%)  3pm cloud amount (oktas) 3pm wind direction  \
# 0                           43                       5.0                  E
# 1                           38                       7.0                 SW
# 2                           59                       4.0                SSW
# 3                           82                       8.0                SSW
# 4                           82                       8.0                SSE
# ..                         ...                       ...                ...
# 207                         65                       7.0                SSE
# 208                         31                       3.0                NNW
# 209                         84                       7.0                  S
# 210                         45                       1.0                NNW
# 211                         43                       6.0                  N
#
#     3pm wind speed (km/h)  3pm MSL pressure (hPa)
# 0                      13                  1015.3
# 1                       4                  1008.5
# 2                       2                  1005.2
# 3                      17                  1011.0
# 4                      19                  1013.3
# ..                    ...                     ...
# 207                     7                  1017.4
# 208                    24                  1013.5
# 209                     6                  1010.4
# 210                    28                  1013.2
# 211                    30                  1012.2
#
# [212 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 0 to 211
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   PRICECATEG                         212 non-null    int64
#  1   Minimum temperature (°C)           211 non-null    float64
#  2   Maximum temperature (°C)           211 non-null    float64
#  3   Rainfall (mm)                      211 non-null    float64
#  4   Evaporation (mm)                   212 non-null    float64
#  5   Sunshine (hours)                   212 non-null    float64
#  6   Direction of maximum wind gust     209 non-null    object
#  7   Speed of maximum wind gust (km/h)  209 non-null    float64
#  8   Time of maximum wind gust          209 non-null    object
#  9   9am Temperature (°C)               211 non-null    float64
#  10  9am relative humidity (%)          211 non-null    float64
#  11  9am cloud amount (oktas)           212 non-null    int64
#  12  9am wind direction                 211 non-null    object
#  13  9am wind speed (km/h)              211 non-null    object
#  14  9am MSL pressure (hPa)             210 non-null    float64
#  15  3pm Temperature (°C)               212 non-null    float64
#  16  3pm relative humidity (%)          212 non-null    int64
#  17  3pm cloud amount (oktas)           211 non-null    float64
#  18  3pm wind direction                 212 non-null    object
#  19  3pm wind speed (km/h)              212 non-null    object
#  20  3pm MSL pressure (hPa)             211 non-null    float64
# dtypes: float64(12), int64(3), object(6)
# memory usage: 36.4+ KB

# %%
# display categorical columns
df[df.select_dtypes(include=['object']).columns]
# Out:
#     Direction of maximum wind gust  Time of maximum wind gust  \
# 0                               NNE                     13:14
# 1                               NNW                      8:22
# 2                               WSW                     17:55
# 3                               SSE                     16:03
# 4                               SSE                     11:02
# ..                              ...                       ...
# 207                             SSW                     12:18
# 208                               N                     13:14
# 209                             NNE                      1:50
# 210                             NNW                     14:04
# 211                               N                     16:29
#
#     9am wind direction 9am wind speed (km/h) 3pm wind direction  \
# 0                    N                     2                  E
# 1                  NNW                    17                 SW
# 2                  WSW                     4                SSW
# 3                  SSE                    11                SSW
# 4                  SSE                    13                SSE
# ..                 ...                   ...                ...
# 207                                     Calm                SSE
# 208                  N                     7                NNW
# 209                  N                    13                  S
# 210                  N                    15                NNW
# 211                  N                    17                  N
#
#     3pm wind speed (km/h)
# 0                      13
# 1                       4
# 2                       2
# 3                      17
# 4                      19
# ..                    ...
# 207                     7
# 208                    24
# 209                     6
# 210                    28
# 211                    30
#
# [212 rows x 6 columns]

# %%
df[df.select_dtypes(include=['object']).columns]
# Out:
#     Direction of maximum wind gust  Time of maximum wind gust  \
# 0                               NNE                     13:14
# 1                               NNW                      8:22
# 2                               WSW                     17:55
# 3                               SSE                     16:03
# 4                               SSE                     11:02
# ..                              ...                       ...
# 207                             SSW                     12:18
# 208                               N                     13:14
# 209                             NNE                      1:50
# 210                             NNW                     14:04
# 211                               N                     16:29
#
#     9am wind direction 9am wind speed (km/h) 3pm wind direction  \
# 0                    N                     2                  E
# 1                  NNW                    17                 SW
# 2                  WSW                     4                SSW
# 3                  SSE                    11                SSW
# 4                  SSE                    13                SSE
# ..                 ...                   ...                ...
# 207                                     Calm                SSE
# 208                  N                     7                NNW
# 209                  N                    13                  S
# 210                  N                    15                NNW
# 211                  N                    17                  N
#
#     3pm wind speed (km/h)
# 0                      13
# 1                       4
# 2                       2
# 3                      17
# 4                      19
# ..                    ...
# 207                     7
# 208                    24
# 209                     6
# 210                    28
# 211                    30
#
# [212 rows x 6 columns]

# %%
df['9am wind speed (km/h)']= pd.to_numeric(df['9am wind speed (km/h)'], errors='coerce')
df['3pm wind speed (km/h)']= pd.to_numeric(df['3pm wind speed (km/h)'], errors='coerce')

# %%
to_drop = ['Time of maximum wind gust']
df.drop(to_drop, axis=1, inplace=True)

# %%
df
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 207            0.0               1.2               3.8
# 208            0.0               1.6               9.6
# 209            0.6               6.4               4.3
# 210            4.0               1.4               7.4
# 211            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 207                             SSW                               15.0
# 208                               N                               39.0
# 209                             NNE                               33.0
# 210                             NNW                               50.0
# 211                               N                               61.0
#
#      9am Temperature (°C)  9am relative humidity (%)  \
# 0                    19.2                       77.0
# 1                    23.3                       52.0
# 2                    18.3                      100.0
# 3                    16.2                       98.0
# 4                    17.2                       96.0
# ..                    ...                        ...
# 207                   7.7                       88.0
# 208                   9.1                       80.0
# 209                  10.6                       79.0
# 210                  11.1                       70.0
# 211                  13.5                       53.0
#
#      9am cloud amount (oktas) 9am wind direction  9am wind speed (km/h)  \
# 0                           6                  N                    2.0
# 1                           7                NNW                   17.0
# 2                           8                WSW                    4.0
# 3                           8                SSE                   11.0
# 4                           8                SSE                   13.0
# ..                        ...                ...                    ...
# 207                         7                                       NaN
# 208                         1                  N                    7.0
# 209                         7                  N                   13.0
# 210                         7                  N                   15.0
# 211                         7                  N                   17.0
#
#      9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0                    1018.8                  28.1                         43
# 1                    1013.3                  28.7                         38
# 2                    1007.7                  23.5                         59
# 3                    1010.0                  18.2                         82
# 4                    1012.5                  18.2                         82
# ..                      ...                   ...                        ...
# 207                  1020.0                  12.8                         65
# 208                  1018.6                  17.4                         31
# 209                  1011.4                  12.8                         84
# 210                  1016.1                  16.8                         45
# 211                     NaN                  19.4                         43
#
#      3pm cloud amount (oktas) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         5.0                  E                   13.0
# 1                         7.0                 SW                    4.0
# 2                         4.0                SSW                    2.0
# 3                         8.0                SSW                   17.0
# 4                         8.0                SSE                   19.0
# ..                        ...                ...                    ...
# 207                       7.0                SSE                    7.0
# 208                       3.0                NNW                   24.0
# 209                       7.0                  S                    6.0
# 210                       1.0                NNW                   28.0
# 211                       6.0                  N                   30.0
#
#      3pm MSL pressure (hPa)
# 0                    1015.3
# 1                    1008.5
# 2                    1005.2
# 3                    1011.0
# 4                    1013.3
# ..                      ...
# 207                  1017.4
# 208                  1013.5
# 209                  1010.4
# 210                  1013.2
# 211                  1012.2
#
# [212 rows x 20 columns]

# %%
# fill missing values with the mean
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# fill missing string with mode
cat_columns = df.select_dtypes(include=['object']).columns
df[cat_columns] = df[cat_columns].fillna(df[cat_columns].mode().iloc[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 0 to 211
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   PRICECATEG                         212 non-null    int64
#  1   Minimum temperature (°C)           212 non-null    float64
#  2   Maximum temperature (°C)           212 non-null    float64
#  3   Rainfall (mm)                      212 non-null    float64
#  4   Evaporation (mm)                   212 non-null    float64
#  5   Sunshine (hours)                   212 non-null    float64
#  6   Direction of maximum wind gust     212 non-null    object
#  7   Speed of maximum wind gust (km/h)  212 non-null    float64
#  8   9am Temperature (°C)               212 non-null    float64
#  9   9am relative humidity (%)          212 non-null    float64
#  10  9am cloud amount (oktas)           212 non-null    int64
#  11  9am wind direction                 212 non-null    object
#  12  9am wind speed (km/h)              212 non-null    float64
#  13  9am MSL pressure (hPa)             212 non-null    float64
#  14  3pm Temperature (°C)               212 non-null    float64
#  15  3pm relative humidity (%)          212 non-null    int64
#  16  3pm cloud amount (oktas)           212 non-null    float64
#  17  3pm wind direction                 212 non-null    object
#  18  3pm wind speed (km/h)              212 non-null    float64
#  19  3pm MSL pressure (hPa)             212 non-null    float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 34.8+ KB

# %%
X = df.drop("PRICECATEG", axis=1)
y = df["PRICECATEG"]

# %%
X
# Out:
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                        15.6                      29.9            0.0
# 1                        18.4                      29.0            0.0
# 2                        17.0                      26.2           12.6
# 3                        16.0                      18.6            2.6
# 4                        15.9                      19.1           11.2
# ..                        ...                       ...            ...
# 207                       4.6                      13.6            0.0
# 208                       5.3                      17.8            0.0
# 209                       9.1                      16.2            0.6
# 210                       6.4                      17.6            4.0
# 211                      11.0                      20.1            0.0
#
#      Evaporation (mm)  Sunshine (hours) Direction of maximum wind gust   \
# 0                 2.8               9.3                             NNE
# 1                 9.4               1.3                             NNW
# 2                 4.8               7.1                             WSW
# 3                 3.8               0.0                             SSE
# 4                 1.0               0.0                             SSE
# ..                ...               ...                             ...
# 207               1.2               3.8                             SSW
# 208               1.6               9.6                               N
# 209               6.4               4.3                             NNE
# 210               1.4               7.4                             NNW
# 211               5.8               3.6                               N
#
#      Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# 0                                 31.0                  19.2
# 1                                 30.0                  23.3
# 2                                 33.0                  18.3
# 3                                 41.0                  16.2
# 4                                 35.0                  17.2
# ..                                 ...                   ...
# 207                               15.0                   7.7
# 208                               39.0                   9.1
# 209                               33.0                  10.6
# 210                               50.0                  11.1
# 211                               61.0                  13.5
#
#      9am relative humidity (%)  9am cloud amount (oktas) 9am wind direction  \
# 0                         77.0                         6                  N
# 1                         52.0                         7                NNW
# 2                        100.0                         8                WSW
# 3                         98.0                         8                SSE
# 4                         96.0                         8                SSE
# ..                         ...                       ...                ...
# 207                       88.0                         7
# 208                       80.0                         1                  N
# 209                       79.0                         7                  N
# 210                       70.0                         7                  N
# 211                       53.0                         7                  N
#
#      9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                 2.000000             1018.800000                  28.1
# 1                17.000000             1013.300000                  28.7
# 2                 4.000000             1007.700000                  23.5
# 3                11.000000             1010.000000                  18.2
# 4                13.000000             1012.500000                  18.2
# ..                     ...                     ...                   ...
# 207              10.361809             1020.000000                  12.8
# 208               7.000000             1018.600000                  17.4
# 209              13.000000             1011.400000                  12.8
# 210              15.000000             1016.100000                  16.8
# 211              17.000000             1017.861905                  19.4
#
#      3pm relative humidity (%)  3pm cloud amount (oktas) 3pm wind direction  \
# 0                           43                       5.0                  E
# 1                           38                       7.0                 SW
# 2                           59                       4.0                SSW
# 3                           82                       8.0                SSW
# 4                           82                       8.0                SSE
# ..                         ...                       ...                ...
# 207                         65                       7.0                SSE
# 208                         31                       3.0                NNW
# 209                         84                       7.0                  S
# 210                         45                       1.0                NNW
# 211                         43                       6.0                  N
#
#      3pm wind speed (km/h)  3pm MSL pressure (hPa)
# 0                     13.0                  1015.3
# 1                      4.0                  1008.5
# 2                      2.0                  1005.2
# 3                     17.0                  1011.0
# 4                     19.0                  1013.3
# ..                     ...                     ...
# 207                    7.0                  1017.4
# 208                   24.0                  1013.5
# 209                    6.0                  1010.4
# 210                   28.0                  1013.2
# 211                   30.0                  1012.2
#
# [212 rows x 19 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 207    3
# 208    1
# 209    3
# 210    2
# 211    1
# Name: PRICECATEG, Length: 212, dtype: int64

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

cat_columns = X.select_dtypes(include=['object']).columns

for col in cat_columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

# %%
X
# Out:
#      Minimum temperature (°C)  Maximum temperature (°C)  Rainfall (mm)  \
# 0                        15.6                      29.9            0.0
# 1                        18.4                      29.0            0.0
# 2                        17.0                      26.2           12.6
# 3                        16.0                      18.6            2.6
# 4                        15.9                      19.1           11.2
# ..                        ...                       ...            ...
# 207                       4.6                      13.6            0.0
# 208                       5.3                      17.8            0.0
# 209                       9.1                      16.2            0.6
# 210                       6.4                      17.6            4.0
# 211                      11.0                      20.1            0.0
#
#      Evaporation (mm)  Sunshine (hours)  Direction of maximum wind gust   \
# 0                 2.8               9.3                                4
# 1                 9.4               1.3                                5
# 2                 4.8               7.1                               14
# 3                 3.8               0.0                                9
# 4                 1.0               0.0                                9
# ..                ...               ...                              ...
# 207               1.2               3.8                               10
# 208               1.6               9.6                                2
# 209               6.4               4.3                                4
# 210               1.4               7.4                                5
# 211               5.8               3.6                                2
#
#      Speed of maximum wind gust (km/h)  9am Temperature (°C)  \
# 0                                 31.0                  19.2
# 1                                 30.0                  23.3
# 2                                 33.0                  18.3
# 3                                 41.0                  16.2
# 4                                 35.0                  17.2
# ..                                 ...                   ...
# 207                               15.0                   7.7
# 208                               39.0                   9.1
# 209                               33.0                  10.6
# 210                               50.0                  11.1
# 211                               61.0                  13.5
#
#      9am relative humidity (%)  9am cloud amount (oktas)  9am wind direction  \
# 0                         77.0                         6                   4
# 1                         52.0                         7                   7
# 2                        100.0                         8                  16
# 3                         98.0                         8                  11
# 4                         96.0                         8                  11
# ..                         ...                       ...                 ...
# 207                       88.0                         7                   0
# 208                       80.0                         1                   4
# 209                       79.0                         7                   4
# 210                       70.0                         7                   4
# 211                       53.0                         7                   4
#
#      9am wind speed (km/h)  9am MSL pressure (hPa)  3pm Temperature (°C)  \
# 0                 2.000000             1018.800000                  28.1
# 1                17.000000             1013.300000                  28.7
# 2                 4.000000             1007.700000                  23.5
# 3                11.000000             1010.000000                  18.2
# 4                13.000000             1012.500000                  18.2
# ..                     ...                     ...                   ...
# 207              10.361809             1020.000000                  12.8
# 208               7.000000             1018.600000                  17.4
# 209              13.000000             1011.400000                  12.8
# 210              15.000000             1016.100000                  16.8
# 211              17.000000             1017.861905                  19.4
#
#      3pm relative humidity (%)  3pm cloud amount (oktas)  3pm wind direction  \
# 0                           43                       5.0                   1
# 1                           38                       7.0                  13
# 2                           59                       4.0                  12
# 3                           82                       8.0                  12
# 4                           82                       8.0                  11
# ..                         ...                       ...                 ...
# 207                         65                       7.0                  11
# 208                         31                       3.0                   7
# 209                         84                       7.0                   9
# 210                         45                       1.0                   7
# 211                         43                       6.0                   4
#
#      3pm wind speed (km/h)  3pm MSL pressure (hPa)
# 0                     13.0                  1015.3
# 1                      4.0                  1008.5
# 2                      2.0                  1005.2
# 3                     17.0                  1011.0
# 4                     19.0                  1013.3
# ..                     ...                     ...
# 207                    7.0                  1017.4
# 208                   24.0                  1013.5
# 209                    6.0                  1010.4
# 210                   28.0                  1013.2
# 211                   30.0                  1012.2
#
# [212 rows x 19 columns]

# %%
df
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 207            0.0               1.2               3.8
# 208            0.0               1.6               9.6
# 209            0.6               6.4               4.3
# 210            4.0               1.4               7.4
# 211            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 207                             SSW                               15.0
# 208                               N                               39.0
# 209                             NNE                               33.0
# 210                             NNW                               50.0
# 211                               N                               61.0
#
#      9am Temperature (°C)  9am relative humidity (%)  \
# 0                    19.2                       77.0
# 1                    23.3                       52.0
# 2                    18.3                      100.0
# 3                    16.2                       98.0
# 4                    17.2                       96.0
# ..                    ...                        ...
# 207                   7.7                       88.0
# 208                   9.1                       80.0
# 209                  10.6                       79.0
# 210                  11.1                       70.0
# 211                  13.5                       53.0
#
#      9am cloud amount (oktas) 9am wind direction  9am wind speed (km/h)  \
# 0                           6                  N               2.000000
# 1                           7                NNW              17.000000
# 2                           8                WSW               4.000000
# 3                           8                SSE              11.000000
# 4                           8                SSE              13.000000
# ..                        ...                ...                    ...
# 207                         7                                 10.361809
# 208                         1                  N               7.000000
# 209                         7                  N              13.000000
# 210                         7                  N              15.000000
# 211                         7                  N              17.000000
#
#      9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0               1018.800000                  28.1                         43
# 1               1013.300000                  28.7                         38
# 2               1007.700000                  23.5                         59
# 3               1010.000000                  18.2                         82
# 4               1012.500000                  18.2                         82
# ..                      ...                   ...                        ...
# 207             1020.000000                  12.8                         65
# 208             1018.600000                  17.4                         31
# 209             1011.400000                  12.8                         84
# 210             1016.100000                  16.8                         45
# 211             1017.861905                  19.4                         43
#
#      3pm cloud amount (oktas) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         5.0                  E                   13.0
# 1                         7.0                 SW                    4.0
# 2                         4.0                SSW                    2.0
# 3                         8.0                SSW                   17.0
# 4                         8.0                SSE                   19.0
# ..                        ...                ...                    ...
# 207                       7.0                SSE                    7.0
# 208                       3.0                NNW                   24.0
# 209                       7.0                  S                    6.0
# 210                       1.0                NNW                   28.0
# 211                       6.0                  N                   30.0
#
#      3pm MSL pressure (hPa)
# 0                    1015.3
# 1                    1008.5
# 2                    1005.2
# 3                    1011.0
# 4                    1013.3
# ..                      ...
# 207                  1017.4
# 208                  1013.5
# 209                  1010.4
# 210                  1013.2
# 211                  1012.2
#
# [212 rows x 20 columns]

# %%
df['Avg Temp'] = pd.DataFrame((df['Minimum temperature (°C)'] + df['Maximum temperature (°C)'])/2)

# %%
df['AvgdayTemp'] = pd.DataFrame((df['3pm Temperature (°C)'] + df['9am Temperature (°C)'])/2)

# %%
df['Avghumidity']= pd.DataFrame((df['9am relative humidity (%)'] + df['3pm relative humidity (%)'])/2)

# %%
df['Vartoavgmaxtemp'] = pd.DataFrame((df['Maximum temperature (°C)'] - df['Maximum temperature (°C)'].mean()).abs())

# %%
df
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 0              0.0               2.8               9.3
# 1              0.0               9.4               1.3
# 2             12.6               4.8               7.1
# 3              2.6               3.8               0.0
# 4             11.2               1.0               0.0
# ..             ...               ...               ...
# 207            0.0               1.2               3.8
# 208            0.0               1.6               9.6
# 209            0.6               6.4               4.3
# 210            4.0               1.4               7.4
# 211            0.0               5.8               3.6
#
#     Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 0                               NNE                               31.0
# 1                               NNW                               30.0
# 2                               WSW                               33.0
# 3                               SSE                               41.0
# 4                               SSE                               35.0
# ..                              ...                                ...
# 207                             SSW                               15.0
# 208                               N                               39.0
# 209                             NNE                               33.0
# 210                             NNW                               50.0
# 211                               N                               61.0
#
#      9am Temperature (°C)  9am relative humidity (%)  \
# 0                    19.2                       77.0
# 1                    23.3                       52.0
# 2                    18.3                      100.0
# 3                    16.2                       98.0
# 4                    17.2                       96.0
# ..                    ...                        ...
# 207                   7.7                       88.0
# 208                   9.1                       80.0
# 209                  10.6                       79.0
# 210                  11.1                       70.0
# 211                  13.5                       53.0
#
#      9am cloud amount (oktas) 9am wind direction  9am wind speed (km/h)  \
# 0                           6                  N               2.000000
# 1                           7                NNW              17.000000
# 2                           8                WSW               4.000000
# 3                           8                SSE              11.000000
# 4                           8                SSE              13.000000
# ..                        ...                ...                    ...
# 207                         7                                 10.361809
# 208                         1                  N               7.000000
# 209                         7                  N              13.000000
# 210                         7                  N              15.000000
# 211                         7                  N              17.000000
#
#      9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 0               1018.800000                  28.1                         43
# 1               1013.300000                  28.7                         38
# 2               1007.700000                  23.5                         59
# 3               1010.000000                  18.2                         82
# 4               1012.500000                  18.2                         82
# ..                      ...                   ...                        ...
# 207             1020.000000                  12.8                         65
# 208             1018.600000                  17.4                         31
# 209             1011.400000                  12.8                         84
# 210             1016.100000                  16.8                         45
# 211             1017.861905                  19.4                         43
#
#      3pm cloud amount (oktas) 3pm wind direction  3pm wind speed (km/h)  \
# 0                         5.0                  E                   13.0
# 1                         7.0                 SW                    4.0
# 2                         4.0                SSW                    2.0
# 3                         8.0                SSW                   17.0
# 4                         8.0                SSE                   19.0
# ..                        ...                ...                    ...
# 207                       7.0                SSE                    7.0
# 208                       3.0                NNW                   24.0
# 209                       7.0                  S                    6.0
# 210                       1.0                NNW                   28.0
# 211                       6.0                  N                   30.0
#
#      3pm MSL pressure (hPa)  Avg Temp  AvgdayTemp  Vartoavgmaxtemp  \
# 0                    1015.3     22.75       23.65         10.57346
# 1                    1008.5     23.70       26.00          9.67346
# 2                    1005.2     21.60       20.90          6.87346
# 3                    1011.0     17.30       17.20          0.72654
# 4                    1013.3     17.50       17.70          0.22654
# ..                      ...       ...         ...              ...
# 207                  1017.4      9.10       10.25          5.72654
# 208                  1013.5     11.55       13.25          1.52654
# 209                  1010.4     12.65       11.70          3.12654
# 210                  1013.2     12.00       13.95          1.72654
# 211                  1012.2     15.55       16.45          0.77346
#
#      Avghumidity
# 0           60.0
# 1           45.0
# 2           79.5
# 3           90.0
# 4           89.0
# ..           ...
# 207         76.5
# 208         55.5
# 209         81.5
# 210         57.5
# 211         48.0
#
# [212 rows x 24 columns]

# %%
corr_matrix = df.corr()

# %%
corr_matrix['PRICECATEG'].sort_values(ascending=False)
# Out:
# PRICECATEG                           1.000000
# Avghumidity                          0.261211
# 9am relative humidity (%)            0.234860
# 3pm relative humidity (%)            0.199015
# 9am MSL pressure (hPa)               0.150418
# 3pm cloud amount (oktas)             0.138527
# 3pm MSL pressure (hPa)               0.130284
# 9am wind speed (km/h)                0.026492
# Vartoavgmaxtemp                     -0.011280
# 9am cloud amount (oktas)            -0.013437
# Rainfall (mm)                       -0.067422
# 3pm wind speed (km/h)               -0.130714
# Speed of maximum wind gust (km/h)   -0.131190
# Sunshine (hours)                    -0.225787
# Evaporation (mm)                    -0.422854
# Minimum temperature (°C)            -0.432326
# 9am Temperature (°C)                -0.442047
# Maximum temperature (°C)            -0.442108
# 3pm Temperature (°C)                -0.459555
# Avg Temp                            -0.474791
# AvgdayTemp                          -0.484543
# Name: PRICECATEG, dtype: float64

# %%
#A strong negative correlation between 3pm temperature,maximum temperature,9am temperature,minimum temperature,Evaporation
#Sunshine hours.
#Positive correlation: 9am relative humidity (%),3pm relative humidity (%)

# %%
to_drop = ['9am MSL pressure (hPa)','3pm cloud amount (oktas)','9am relative humidity (%)','3pm relative humidity (%)',
          '3pm MSL pressure (hPa)','9am wind speed (km/h)','Vartoavgmaxtemp','9am cloud amount (oktas)','Rainfall (mm)',
          '3pm wind speed (km/h)','Speed of maximum wind gust (km/h)']
X = df.drop(to_drop, axis=1)

# %%
X
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Evaporation (mm)  Sunshine (hours) Direction of maximum wind gust   \
# 0                 2.8               9.3                             NNE
# 1                 9.4               1.3                             NNW
# 2                 4.8               7.1                             WSW
# 3                 3.8               0.0                             SSE
# 4                 1.0               0.0                             SSE
# ..                ...               ...                             ...
# 207               1.2               3.8                             SSW
# 208               1.6               9.6                               N
# 209               6.4               4.3                             NNE
# 210               1.4               7.4                             NNW
# 211               5.8               3.6                               N
#
#      9am Temperature (°C) 9am wind direction  3pm Temperature (°C)  \
# 0                    19.2                  N                  28.1
# 1                    23.3                NNW                  28.7
# 2                    18.3                WSW                  23.5
# 3                    16.2                SSE                  18.2
# 4                    17.2                SSE                  18.2
# ..                    ...                ...                   ...
# 207                   7.7                                     12.8
# 208                   9.1                  N                  17.4
# 209                  10.6                  N                  12.8
# 210                  11.1                  N                  16.8
# 211                  13.5                  N                  19.4
#
#     3pm wind direction  Avg Temp  AvgdayTemp  Avghumidity
# 0                    E     22.75       23.65         60.0
# 1                   SW     23.70       26.00         45.0
# 2                  SSW     21.60       20.90         79.5
# 3                  SSW     17.30       17.20         90.0
# 4                  SSE     17.50       17.70         89.0
# ..                 ...       ...         ...          ...
# 207                SSE      9.10       10.25         76.5
# 208                NNW     11.55       13.25         55.5
# 209                  S     12.65       11.70         81.5
# 210                NNW     12.00       13.95         57.5
# 211                  N     15.55       16.45         48.0
#
# [212 rows x 13 columns]

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder

cat_columns = X.select_dtypes(include=['object']).columns

for col in cat_columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

# %%
corr_matrix1 = X.corr()

# %%
corr_matrix1['PRICECATEG'].sort_values(ascending=False)
# Out:
# PRICECATEG                         1.000000
# Avghumidity                        0.261211
# Direction of maximum wind gust    -0.038461
# 3pm wind direction                -0.114437
# 9am wind direction                -0.123607
# Sunshine (hours)                  -0.225787
# Evaporation (mm)                  -0.422854
# Minimum temperature (°C)          -0.432326
# 9am Temperature (°C)              -0.442047
# Maximum temperature (°C)          -0.442108
# 3pm Temperature (°C)              -0.459555
# Avg Temp                          -0.474791
# AvgdayTemp                        -0.484543
# Name: PRICECATEG, dtype: float64

# %%
#avoid wind
X.drop('3pm wind direction',axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [155], in <cell line: 2>()
#       1 #avoid wind
# ----> 2 X.drop('3pm wind direction',axis=1, inplace = True)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['3pm wind direction'] not found in axis"

# %%
X.drop('9am wind direction ',axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
# ----> 1 X.drop('9am wind direction ',axis=1, inplace = True)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['9am wind direction '] not found in axis"

# %%
X.drop('Direction of maximum wind gust ',axis=1, inplace = True)

# %%
X
# Out:
#      PRICECATEG  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0             0                      15.6                      29.9
# 1             1                      18.4                      29.0
# 2             0                      17.0                      26.2
# 3             1                      16.0                      18.6
# 4             1                      15.9                      19.1
# ..          ...                       ...                       ...
# 207           3                       4.6                      13.6
# 208           1                       5.3                      17.8
# 209           3                       9.1                      16.2
# 210           2                       6.4                      17.6
# 211           1                      11.0                      20.1
#
#      Evaporation (mm)  Sunshine (hours)  9am Temperature (°C)  \
# 0                 2.8               9.3                  19.2
# 1                 9.4               1.3                  23.3
# 2                 4.8               7.1                  18.3
# 3                 3.8               0.0                  16.2
# 4                 1.0               0.0                  17.2
# ..                ...               ...                   ...
# 207               1.2               3.8                   7.7
# 208               1.6               9.6                   9.1
# 209               6.4               4.3                  10.6
# 210               1.4               7.4                  11.1
# 211               5.8               3.6                  13.5
#
#      3pm Temperature (°C)  Avg Temp  AvgdayTemp  Avghumidity
# 0                    28.1     22.75       23.65         60.0
# 1                    28.7     23.70       26.00         45.0
# 2                    23.5     21.60       20.90         79.5
# 3                    18.2     17.30       17.20         90.0
# 4                    18.2     17.50       17.70         89.0
# ..                    ...       ...         ...          ...
# 207                  12.8      9.10       10.25         76.5
# 208                  17.4     11.55       13.25         55.5
# 209                  12.8     12.65       11.70         81.5
# 210                  16.8     12.00       13.95         57.5
# 211                  19.4     15.55       16.45         48.0
#
# [212 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %%
# replace Low to 0, Medium to 1, High to 2
#y_train = y_train.replace({'LOW': 0, 'MEDIUM': 1, 'HIGH': 2})
#y_test = y_test.replace({'LOW': 0, 'MEDIUM': 1, 'HIGH': 2})

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#K-Nearest Neighbour classification

from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

print("Accuracy: ", accuracy_score(y_test, y_pred))

print("Confusion Matrix: ", confusion_matrix(y_test, y_pred))

print("Classification Report: ", classification_report(y_test, y_pred))


# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()


# plot roc curve
from sklearn.metrics import roc_curve, roc_auc_score

y_pred_proba = knn.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='KNeighborsClassifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('KNeighborsClassifier ROC Curve')
plt.show()
# Out:
# Accuracy:  0.7764705882352941
# Confusion Matrix:  [[ 4 10]
#  [ 9 62]]
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.31      0.29      0.30        14
#            1       0.86      0.87      0.87        71
#
#     accuracy                           0.78        85
#    macro avg       0.58      0.58      0.58        85
# weighted avg       0.77      0.78      0.77        85

# %%
# Decision Tree

from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()

dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

print("Accuracy: ", accuracy_score(y_test, y_pred))

print("Confusion Matrix: ", confusion_matrix(y_test, y_pred))

print("Classification Report: ", classification_report(y_test, y_pred))


# plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d")
plt.show()

# plot roc curve
from sklearn.metrics import roc_curve, roc_auc_score

y_pred_proba = dt.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Decision Tree Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Decision Tree ROC Curve')
plt.show()
# Out:
# Accuracy:  0.6941176470588235
# Confusion Matrix:  [[ 7  7]
#  [19 52]]
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.27      0.50      0.35        14
#            1       0.88      0.73      0.80        71
#
#     accuracy                           0.69        85
#    macro avg       0.58      0.62      0.58        85
# weighted avg       0.78      0.69      0.73        85
