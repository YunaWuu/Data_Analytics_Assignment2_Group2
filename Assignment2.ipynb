# %%
import pandas as pd

# %%
weather = pd.read_csv('weather_data.csv')

# %%
weather.head(20)
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 0    1/01/2021                      15.6                      29.9
# 1    2/01/2021                      18.4                      29.0
# 2    3/01/2021                      17.0                      26.2
# 3    4/01/2021                      16.0                      18.6
# 4    5/01/2021                      15.9                      19.1
# 5    6/01/2021                      13.7                      19.2
# 6    7/01/2021                      14.7                      25.7
# 7    8/01/2021                      12.7                      24.3
# 8    9/01/2021                      14.2                      27.9
# 9   10/01/2021                      16.9                      33.5
# 10  11/01/2021                      19.2                      36.7
# 11  12/01/2021                      18.3                      21.6
# 12  13/01/2021                      14.5                      27.0
# ...

# %%
price_demand = pd.read_csv('price_demand_data.csv')

# %%
price_demand.head()
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 0   VIC1  1/01/2021 0:30      4179.21           LOW
# 1   VIC1  1/01/2021 1:00      4047.76           LOW
# 2   VIC1  1/01/2021 1:30      3934.70           LOW
# 3   VIC1  1/01/2021 2:00      3766.45           LOW
# 4   VIC1  1/01/2021 2:30      3590.37           LOW

# %%
price_demand.loc[price_demand['SETTLEMENTDATE'] == '1/01/2021 1:00']
# Out:
#   REGION  SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 1   VIC1  1/01/2021 1:00      4047.76           LOW

# %%
price_demand.loc[price_demand['PRICECATEGORY'] != 'LOW']
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 373     VIC1   8/01/2021 19:00      5352.25        MEDIUM
# 374     VIC1   8/01/2021 19:30      5321.80        MEDIUM
# 417     VIC1   9/01/2021 17:00      5452.03        MEDIUM
# 418     VIC1   9/01/2021 17:30      5653.12        MEDIUM
# 419     VIC1   9/01/2021 18:00      5812.76        MEDIUM
# ...      ...               ...          ...           ...
# 11659   VIC1  31/08/2021 22:00      4861.91        MEDIUM
# 11660   VIC1  31/08/2021 22:30      4748.74        MEDIUM
# 11661   VIC1  31/08/2021 23:00      4620.09        MEDIUM
# 11662   VIC1  31/08/2021 23:30      4834.00        MEDIUM
# 11663   VIC1    1/09/2021 0:00      4811.27        MEDIUM
#
# [4094 rows x 4 columns]

# %%
price_demand['PRICECATEGORY'].value_counts()
# Out:
# LOW        7570
# MEDIUM     3061
# HIGH        777
# EXTREME     256
# Name: PRICECATEGORY, dtype: int64

# %%
price_demand.loc[price_demand['PRICECATEGORY'] == 'HIGH']
# Out:
#       REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 607     VIC1  13/01/2021 16:00      6507.19          HIGH
# 1135    VIC1  24/01/2021 16:00      7162.96          HIGH
# 1136    VIC1  24/01/2021 16:30      7383.25          HIGH
# 1137    VIC1  24/01/2021 17:00      7519.80          HIGH
# 1176    VIC1  25/01/2021 12:30      8196.83          HIGH
# ...      ...               ...          ...           ...
# 11470   VIC1  27/08/2021 23:30      5347.05          HIGH
# 11555   VIC1  29/08/2021 18:00      5775.29          HIGH
# 11559   VIC1  29/08/2021 20:00      5884.18          HIGH
# 11560   VIC1  29/08/2021 20:30      5739.64          HIGH
# 11603   VIC1  30/08/2021 18:00      5725.18          HIGH
#
# [777 rows x 4 columns]

# %%
price_demand.loc[price_demand['SETTLEMENTDATE'] == '25/01/2021 12:30']
# Out:
#      REGION    SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY
# 1176   VIC1  25/01/2021 12:30      8196.83          HIGH

# %%
weather.loc[weather['Date'] == '25/01/2021']
# Out:
#           Date  Minimum temperature (°C)  Maximum temperature (°C)  \
# 24  25/01/2021                      22.2                      39.2
#
#     Rainfall (mm)  Evaporation (mm)  Sunshine (hours)  \
# 24            0.0              13.8               3.5
#
#    Direction of maximum wind gust   Speed of maximum wind gust (km/h)  \
# 24                               W                               54.0
#
#    Time of maximum wind gust  9am Temperature (°C)  ...  \
# 24                     15:37                  30.9  ...
#
#     9am cloud amount (oktas)  9am wind direction 9am wind speed (km/h)  \
# 24                         5                   N                    13
#
#    9am MSL pressure (hPa)  3pm Temperature (°C)  3pm relative humidity (%)  \
# 24                 1001.3                  26.6                         47
#
#     3pm cloud amount (oktas)  3pm wind direction 3pm wind speed (km/h)  \
# 24                       7.0                 WSW                    11
#
# ...

# %%
price_demand['Date'] = price_demand['SETTLEMENTDATE'].dt.date
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 price_demand['Date'] = price_demand['SETTLEMENTDATE'].dt.date
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...

# %%
price_demand['SETTLEMENTDATE'] = pd.to_datetime(price_demand['SETTLEMENTDATE'])

# %%
price_demand['SETTLEMENTDATE']
# Out:
# 0       2021-01-01 00:30:00
# 1       2021-01-01 01:00:00
# 2       2021-01-01 01:30:00
# 3       2021-01-01 02:00:00
# 4       2021-01-01 02:30:00
#                 ...
# 11659   2021-08-31 22:00:00
# 11660   2021-08-31 22:30:00
# 11661   2021-08-31 23:00:00
# 11662   2021-08-31 23:30:00
# 11663   2021-01-09 00:00:00
# Name: SETTLEMENTDATE, Length: 11664, dtype: datetime64[ns]

# %%
price_demand['DATE'] = price_demand['SETTLEMENTDATE'].dt.date

# %%
price_demand['DATE']
# Out:
# 0        2021-01-01
# 1        2021-01-01
# 2        2021-01-01
# 3        2021-01-01
# 4        2021-01-01
#             ...
# 11659    2021-08-31
# 11660    2021-08-31
# 11661    2021-08-31
# 11662    2021-08-31
# 11663    2021-01-09
# Name: DATE, Length: 11664, dtype: object

# %%
price_demand.head()
# Out:
#   REGION      SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        DATE
# 0   VIC1 2021-01-01 00:30:00      4179.21           LOW  2021-01-01
# 1   VIC1 2021-01-01 01:00:00      4047.76           LOW  2021-01-01
# 2   VIC1 2021-01-01 01:30:00      3934.70           LOW  2021-01-01
# 3   VIC1 2021-01-01 02:00:00      3766.45           LOW  2021-01-01
# 4   VIC1 2021-01-01 02:30:00      3590.37           LOW  2021-01-01

# %%
price_demand.plot(kind = 'scatter', x = 'PRICECATEGORY', y = 'TOTALDEMAND')
# Out:
# <AxesSubplot:xlabel='PRICECATEGORY', ylabel='TOTALDEMAND'>

# %%
price_demand.loc[price_demand['PRICECATEGORY'] == 'HIGH']
# Out:
#       REGION      SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        DATE
# 607     VIC1 2021-01-13 16:00:00      6507.19          HIGH  2021-01-13
# 1135    VIC1 2021-01-24 16:00:00      7162.96          HIGH  2021-01-24
# 1136    VIC1 2021-01-24 16:30:00      7383.25          HIGH  2021-01-24
# 1137    VIC1 2021-01-24 17:00:00      7519.80          HIGH  2021-01-24
# 1176    VIC1 2021-01-25 12:30:00      8196.83          HIGH  2021-01-25
# ...      ...                 ...          ...           ...         ...
# 11470   VIC1 2021-08-27 23:30:00      5347.05          HIGH  2021-08-27
# 11555   VIC1 2021-08-29 18:00:00      5775.29          HIGH  2021-08-29
# 11559   VIC1 2021-08-29 20:00:00      5884.18          HIGH  2021-08-29
# 11560   VIC1 2021-08-29 20:30:00      5739.64          HIGH  2021-08-29
# 11603   VIC1 2021-08-30 18:00:00      5725.18          HIGH  2021-08-30
#
# [777 rows x 5 columns]

# %%
price_demand.loc[(price_demand['PRICECATEGORY'] == 'LOW') & (price_demand['TOTALDEMAND'] > 6000)]
# Out:
#       REGION      SETTLEMENTDATE  TOTALDEMAND PRICECATEGORY        DATE
# 501     VIC1 2021-11-01 11:00:00      6088.52           LOW  2021-11-01
# 502     VIC1 2021-11-01 11:30:00      6254.85           LOW  2021-11-01
# 503     VIC1 2021-11-01 12:00:00      6539.03           LOW  2021-11-01
# 504     VIC1 2021-11-01 12:30:00      6810.91           LOW  2021-11-01
# 505     VIC1 2021-11-01 13:00:00      7007.43           LOW  2021-11-01
# ...      ...                 ...          ...           ...         ...
# 11104   VIC1 2021-08-20 08:30:00      6122.96           LOW  2021-08-20
# 11105   VIC1 2021-08-20 09:00:00      6183.58           LOW  2021-08-20
# 11106   VIC1 2021-08-20 09:30:00      6179.44           LOW  2021-08-20
# 11107   VIC1 2021-08-20 10:00:00      6107.33           LOW  2021-08-20
# 11108   VIC1 2021-08-20 10:30:00      6103.37           LOW  2021-08-20
#
# [190 rows x 5 columns]
